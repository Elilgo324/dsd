# %%
import matplotlib.pyplot as plt
import pandas as pd
import dataframe_image as dfi
from random import random, uniform
from random import randint, seed

# %%
salesman = [(2,0)]
P = [(0,1), (3,5), (1,3), (4,2)]
Q = [(uniform(95,100),uniform(95,100)) for _ in range(40)]

plt.scatter(*zip(*salesman), c='blue')
plt.scatter(*zip(*P), c='red')
plt.scatter(*zip(*Q), c='black')
plt.legend(['salesman','P','Q'])

plt.savefig('tsp-reduction.png')
plt.show()

# %%
solutions = pd.read_csv ('solutions.csv')
solutions = solutions.style.set_properties(**{'text-align': 'left'})
solutions
# Out:
# <style type="text/css">
# #T_0d503_row0_col0, #T_0d503_row0_col1, #T_0d503_row0_col2, #T_0d503_row0_col3, #T_0d503_row1_col0, #T_0d503_row1_col1, #T_0d503_row1_col2, #T_0d503_row1_col3, #T_0d503_row2_col0, #T_0d503_row2_col1, #T_0d503_row2_col2, #T_0d503_row2_col3, #T_0d503_row3_col0, #T_0d503_row3_col1, #T_0d503_row3_col2, #T_0d503_row3_col3, #T_0d503_row4_col0, #T_0d503_row4_col1, #T_0d503_row4_col2, #T_0d503_row4_col3, #T_0d503_row5_col0, #T_0d503_row5_col1, #T_0d503_row5_col2, #T_0d503_row5_col3, #T_0d503_row6_col0, #T_0d503_row6_col1, #T_0d503_row6_col2, #T_0d503_row6_col3, #T_0d503_row7_col0, #T_0d503_row7_col1, #T_0d503_row7_col2, #T_0d503_row7_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_0d503">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0d503_level0_col0" class="col_heading level0 col0" >Planner</th>
#       <th id="T_0d503_level0_col1" class="col_heading level0 col1" >Scenario</th>
#       <th id="T_0d503_level0_col2" class="col_heading level0 col2" >Comlexity</th>
#       <th id="T_0d503_level0_col3" class="col_heading level0 col3" >Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0d503_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0d503_row0_col0" class="data row0 col0" >StaticLine</td>
#       <td id="T_0d503_row0_col1" class="data row0 col1" >full-blockage</td>
#       <td id="T_0d503_row0_col2" class="data row0 col2" >k^3+n^2</td>
#       <td id="T_0d503_row0_col3" class="data row0 col3" >optimal assignment on a full static line</td>
#     </tr>
#     <tr>
#       <th id="T_0d503_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0d503_row1_col0" class="data row1 col0" >TravelingLine</td>
#       <td id="T_0d503_row1_col1" class="data row1 col1" >full-blockage</td>
#       <td id="T_0d503_row1_col2" class="data row1 col2" >k^3+n^3</td>
#       <td id="T_0d503_row1_col3" class="data row1 col3" >a full line with optimal traveling</td>
#     </tr>
#     <tr>
#       <th id="T_0d503_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0d503_row2_col0" class="data row2 col0" >SeparateTraveling</td>
#       <td id="T_0d503_row2_col1" class="data row2 col1" >full-blockage</td>
#       <td id="T_0d503_row2_col2" class="data row2 col2" >k^2n^3+k^3</td>
#       <td id="T_0d503_row2_col3" class="data row2 col3" >TravelingLine in separate buckets</td>
#     </tr>
#     <tr>
#       <th id="T_0d503_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0d503_row3_col0" class="data row3 col0" >StaticLineLack</td>
#       <td id="T_0d503_row3_col1" class="data row3 col1" >partial-blockage</td>
#       <td id="T_0d503_row3_col2" class="data row3 col2" >kn*flow</td>
#       <td id="T_0d503_row3_col3" class="data row3 col3" >a static line with optimal movements on it</td>
#     </tr>
#     <tr>
#       <th id="T_0d503_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0d503_row4_col0" class="data row4 col0" >SeparateStaticLack</td>
#       <td id="T_0d503_row4_col1" class="data row4 col1" >partial-blockage</td>
#       <td id="T_0d503_row4_col2" class="data row4 col2" >k^2n*bucket-flow</td>
#       <td id="T_0d503_row4_col3" class="data row4 col3" >StaticLineLack in separate buckets</td>
#     </tr>
#     <tr>
#       <th id="T_0d503_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0d503_row5_col0" class="data row5 col0" >AdditiveStaticLack</td>
#       <td id="T_0d503_row5_col1" class="data row5 col1" >partial-blockage</td>
#       <td id="T_0d503_row5_col2" class="data row5 col2" >kn*group-flow</td>
#       <td id="T_0d503_row5_col3" class="data row5 col3" >StaticLineLack on separate agent groups</td>
#     </tr>
#     <tr>
#       <th id="T_0d503_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0d503_row6_col0" class="data row6 col0" >IterativeAssignment</td>
#       <td id="T_0d503_row6_col1" class="data row6 col1" >both</td>
#       <td id="T_0d503_row6_col2" class="data row6 col2" >n^4/k+k^2</td>
#       <td id="T_0d503_row6_col3" class="data row6 col3" >iterative optimal assignment</td>
#     </tr>
#     <tr>
#       <th id="T_0d503_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0d503_row7_col0" class="data row7 col0" >KmeansAssignment</td>
#       <td id="T_0d503_row7_col1" class="data row7 col1" >both</td>
#       <td id="T_0d503_row7_col2" class="data row7 col2" >kmeans+k^3+n</td>
#       <td id="T_0d503_row7_col3" class="data row7 col3" >clusters assignment</td>
#     </tr>
#   </tbody>
# </table>

# %%
dfi.export(solutions, 'solutions-table.png')
# Out:
# c:\users\fogle\pycharmprojects\dsd\venv\lib\site-packages\dataframe_image\_pandas_accessor.py:69: FutureWarning: this method is deprecated in favour of `Styler.to_html()`
#   html = '<div>' + obj.render() + '</div>'

# %%
seed(6)

robots = [(randint(1,9),randint(1,3)) for _ in range(5)]
agents = [(uniform(0.1,8.9),uniform(3,8.9)) for _ in range(50)]
locations = [(x,6) for x in range(1,10,2)]

plt.scatter(*zip(*agents), c='red')
plt.scatter(*zip(*robots), c='blue')

plt.legend(['agents','robots'])

plt.savefig('dsd.png')
plt.show()

# %%
seed(6)

robots = [(randint(1,9),randint(1,3)) for _ in range(5)]
agents = [(uniform(0.1,8.9),uniform(3,8.9)) for _ in range(50)]
locations = [(x,6) for x in range(1,10,2)]

plt.scatter(*zip(*agents), c='red')
plt.scatter(*zip(*robots), c='blue')
plt.scatter(*zip(*locations), c='black')

plt.legend(['agents','robots','locations'])

plt.plot([0,10],[6,6],color='black',linestyle='dashed')
plt.plot([0,10],[9,9],color='black',linestyle='dashed')

plt.annotate('h', (10, 5.9))
plt.annotate('b', (10, 8.9))

plt.savefig('static-line.png')
plt.show()

# %%
P = [(2,1),(8,2)]
Q = [(3,4),(3,8),(7,4),(7,8)]

plt.plot([0,10],[4,4],color='black',linestyle='dashed')
plt.plot([0,10],[8,8],color='black',linestyle='dashed')

plt.plot([2,3],[1,4],color='black',linestyle='dotted')
plt.plot([2,3],[1,8],color='black',linestyle='dotted')
plt.plot([8,7],[2,4],color='black',linestyle='dotted')
plt.plot([8,7],[2,8],color='black',linestyle='dotted')

plt.scatter(*zip(*P), c='red')
plt.scatter(*zip(*Q), c='blue')

annotations1 = ['p1','p2']
for i, label in enumerate(annotations1):
    x,y = P[i]
    plt.annotate(label, (x+0.1, y-0.2))

annotations2 = ['q1','q1','q2','q2']
for i, label in enumerate(annotations2):
    x,y = Q[i]
    plt.annotate(label, (x+0.3, y-0.4))


plt.savefig('assignment-preservation.png')
plt.show()

# %%
R = [(8,2),(8,8)]
P = [(3,6),(7,6)]
Q = [(3,4),(7,4)]

plt.plot([0,10],[4,4],color='black',linestyle='dashed')
plt.plot([0,10],[6,6],color='black',linestyle='dashed')

plt.scatter(*zip(*R), c='red')
plt.scatter(*zip(*P), c='blue')
plt.scatter(*zip(*Q), c='blue')

annotations1 = ['r1','r2']
for i, label in enumerate(annotations1):
    x,y = R[i]
    plt.annotate(label, (x+0.1, y-0.2))

annotations2 = ['p1','p2']
for i, label in enumerate(annotations2):
    x,y = P[i]
    plt.annotate(label, (x+0.1, y-0.2))

annotations3 = ['q1','q2']
for i, label in enumerate(annotations3):
    x,y = Q[i]
    plt.annotate(label, (x+0.1, y-0.2))

plt.annotate('h1', (10, 5.9))
plt.annotate('h2', (10, 3.9))

plt.savefig('assignment-violation.png')
plt.show()

# %%
seed(6)

robots = [(6,1),(6,3)]
agents = [(uniform(0.1,9.9),2) for _ in range(50)]

plt.xlabel('vertical')
plt.ylabel('horizontal')

plt.scatter(*zip(*agents), c='red')
plt.scatter(*zip(*robots), c='blue')

plt.legend(['agents','robots'])

plt.plot([6,6],[0,4],color='black',linestyle='dashed')

plt.annotate('h', (6.1, 3.9))

plt.savefig('traveling-line.png')
plt.show()

# %%
A = [(4,6), (4,7)]

plt.plot([0,10],[4,4],color='black',linestyle='dashed')
plt.plot([0,10],[6,6],color='black',linestyle='dashed')

plt.scatter(*zip(*A), c='red')

annotations = ['agent meets h1','agent meets h2']
for i, label in enumerate(annotations):
    x,y = A[i]
    plt.annotate(label, (x + 0.2, y + 0.2))

plt.annotate('h1', (10, 5.9))
plt.annotate('h2', (10, 3.9))
plt.annotate('delta', (9.65, 4.9))

plt.gca().set_ylim([2,8])
plt.savefig('traveling-triangle.png')
plt.show()

# %%
seed(6)

X = [(6,1),(7,1),(8.5,1),(9,1)]
Y = [(4,1),(3.5,1),(2,1)]

plt.scatter(*zip(*X), c='red')
plt.scatter(*zip(*Y), c='red')
plt.scatter([5],[1], c='blue')


annotations1 = ['x1','x2','x3','x4']
for i, label in enumerate(annotations1):
    x,y = X[i]
    plt.annotate(label, (x, 1.004))

annotations2 = ['y1','y2','y3']
for i, label in enumerate(annotations2):
    x,y = Y[i]
    plt.annotate(label, (x, 1.004))

plt.annotate('repairman', (4.5, 1.004))

plt.savefig('trp.png')
plt.show()

# %%
xy = pd.read_csv('xy.csv',index_col=' ')
yx = pd.read_csv('yx.csv',index_col=' ')
xy.head()

dfi.export(xy, 'xy-table.png')
dfi.export(yx, 'yx-table.png')

# %%
seed(6)

agents = [(uniform(1,9),uniform(4,7)) for _ in range(50)]
agents += [(5,10), (6,1)]

plt.scatter(*zip(*agents), c='red')

plt.plot([0,10],[1,1],color='black',linestyle='dashed')
plt.plot([0,10],[10,10],color='black',linestyle='dashed')

plt.annotate('top-down scanner', (6, 9.5))
plt.annotate('bottom-up scanner', (6, 1.4))

plt.savefig('scanner-fails.png')
plt.show()

# %%
seed(6)

robots = [(randint(1,9),randint(1,3)) for _ in range(5)]
agents = [(uniform(0.1,9.9),uniform(3,9.9)) for _ in range(50)]
locations = [(1,5),(3,8),(5,6),(7,7),(9,5)]

plt.scatter(*zip(*agents), c='red')
plt.scatter(*zip(*robots), c='blue')
plt.scatter(*zip(*locations), c='black')

plt.legend(['agents','robots','locations'])

plt.plot([0,2],[5,5],color='black',linestyle='dashed')
plt.plot([2,4],[8,8],color='black',linestyle='dashed')
plt.plot([4,6],[6,6],color='black',linestyle='dashed')
plt.plot([6,8],[7,7],color='black',linestyle='dashed')
plt.plot([8,10],[5,5],color='black',linestyle='dashed')

plt.annotate('B1', (1-0.1, 5.5))
plt.annotate('B2', (3-0.1, 8.5))
plt.annotate('B3', (5-0.1, 6.5))
plt.annotate('B4', (7-0.1, 7.5))
plt.annotate('B5', (9-0.1, 5.5))

plt.savefig('separate-traveling.png')
plt.show()

# %%
seed(6)

robots = [(randint(1,9),randint(1,3)) for _ in range(5)]
agents = [(uniform(0.1,8.9),uniform(3,8.9)) for _ in range(50)]
locations = [(2,6), (5,6), (7,6)]

plt.scatter(*zip(*agents), c='red')
plt.scatter(*zip(*robots), c='blue')
plt.scatter(*zip(*locations), c='black')

plt.legend(['agents','robots','locations'])

plt.plot([0,10],[6,6],color='black',linestyle='dashed')
plt.plot([0,10],[9,9],color='black',linestyle='dashed')

plt.annotate('h', (10, 5.9))
plt.annotate('b', (10, 8.9))

plt.savefig('static-lack.png')
plt.show()

# %%
robots = [(2,2), (5,1), (8,3)]
agents = [(1,6),(2,5),(4,6),(5,7),(9,5),(8,7)]

plt.scatter(*zip(*agents), c='red')
plt.scatter(*zip(*robots), c='blue')

plt.plot([2,2,1],[2,5,6],color='black',linestyle='dotted')
plt.plot([5,4,5],[1,6,7],color='black',linestyle='dotted')
plt.plot([8,9,8],[3,5,7],color='black',linestyle='dotted')

plt.legend(['agents','robots'])
plt.savefig('iterative-good.png')
plt.show()

# %%
robots = [(2,2), (5,1), (8,3)]
agents = [(1,6),(2,5),(4,6),(7.5,7),(9,5),(8,7)]

plt.scatter(*zip(*agents), c='red')
plt.scatter(*zip(*robots), c='blue')

plt.plot([2,2,1],[2,5,6],color='black',linestyle='dotted')
plt.plot([5,4,7.5],[1,6,7],color='black',linestyle='dotted')
plt.plot([8,9,8],[3,5,7],color='black',linestyle='dotted')

plt.legend(['agents','robots'])
plt.savefig('iterative-bad.png')
plt.show()

# %%
robots = [(2,2), (5,1), (8,3)]
agents = [(1,6),(2,5),(4,6),(5,7),(9,5),(8,7)]

plt.scatter(*zip(*agents), c='red')
plt.scatter(*zip(*robots), c='blue')

plt.plot([2,2,1],[2,5,6],color='black',linestyle='dotted')
plt.plot([5,4,5],[1,6,7],color='black',linestyle='dotted')
plt.plot([8,9,8],[3,5,7],color='black',linestyle='dotted')

plt.annotate('cluster 1' , (2, 5.5))
plt.annotate('cluster 2' , (4.5, 5.7))
plt.annotate('cluster 3' , (7.5, 5))

plt.legend(['agents','robots'])
plt.savefig('kmeans-good1.png')
plt.show()

# %%
robots = [(2,2), (5,1), (8,3)]
agents = [(1,6),(2,5),(4,6),(7.5,7),(9,5),(8,7)]

plt.scatter(*zip(*agents), c='red')
plt.scatter(*zip(*robots), c='blue')

plt.plot([2,2,1],[2,5,6],color='black',linestyle='dotted')
plt.plot([5,4,],[1,6,],color='black',linestyle='dotted')
plt.plot([8,9,8, 7.5],[3,5,7,7],color='black',linestyle='dotted')

plt.annotate('cluster 1' , (2, 5.5))
plt.annotate('cluster 2' , (4.4, 5.5))
plt.annotate('cluster 3' , (7.5, 5))

plt.legend(['agents','robots'])
plt.savefig('kmeans-good2.png')
plt.show()
