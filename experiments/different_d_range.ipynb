# %% [markdown]
# # Results of different d values

# %%
import pandas as pd
import matplotlib.pyplot as plt
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)

# %%
results = pd.read_csv('./d_results.csv')
results = results.groupby(['planner','d'], as_index=False).mean()
results.head(100)
# Out:
#              planner    d  num_agents  num_robots    f  active_time  \
# 0  StaticLinePlanner  1.1       100.0   45.300000  2.0    76.784212
# 1  StaticLinePlanner  1.2       100.0   41.533333  2.0    77.222606
# 2  StaticLinePlanner  1.3       100.0   38.466667  2.0    77.331706
# 3  StaticLinePlanner  1.4       100.0   35.700000  2.0    78.122111
# 4  StaticLinePlanner  1.5       100.0   33.366667  2.0    77.532557
# 5  StaticLinePlanner  1.6       100.0   31.233333  2.0    77.632616
# 6  StaticLinePlanner  1.7       100.0   29.533333  2.0    77.087248
# 7  StaticLinePlanner  1.8       100.0   27.866667  2.0    77.892531
# 8  StaticLinePlanner  1.9       100.0   26.533333  2.0    77.108839
# 9  StaticLinePlanner  2.0       100.0   24.966667  2.0    76.419758
#
#    planner_time        damage  num_disabled
# 0      0.009108  13683.448906     75.233333
# 1      0.008691  13722.983346     75.100000
# 2      0.008481  13727.264433     75.233333
# ...

# %%
static_line_results = results.loc[results['planner']=='StaticLinePlanner']
traveling_line_results = results.loc[results['planner']=='TravelingLinePlanner']
separate_traveling_results = results.loc[results['planner']=='SeparateTravelingPlanner']
iterative_assignment_results = results.loc[results['planner']=='IterativeAssignmentPlanner']
clustering_assignment_results = results.loc[results['planner']=='ClusteringAssignmentPlanner']

# %% [markdown]
# ## Experiments
#
# ### damage as function of #agents
#
# * the world is 100X300
# * agents initialized in the bottom 100X100 square
# * robots initialized somewhere under the world
# * robots num is sufficient for full-blockage
# * disablement range is 5
# * agent speed v is 1
# * robot speed fv is 2

# %%
title = 'damage as function of d'
plt.title(title)
plt.xlabel('d')
plt.ylabel('damage')
plt.plot(list(static_line_results['d']),list(static_line_results['damage']))
plt.plot(list(traveling_line_results['d']),list(traveling_line_results['damage']))
plt.plot(list(separate_traveling_results['d']),list(separate_traveling_results['damage']))
plt.plot(list(iterative_assignment_results['d']),list(iterative_assignment_results['damage']))
plt.plot(list(clustering_assignment_results['d']),list(clustering_assignment_results['damage']))
plt.legend(['static line', 'traveling line','separate traveling','iterative assignment','clustering assignment'])
# plt.savefig('./plots/'+title+'.png')
plt.show()

# %% [markdown]
# ### active time as function of #agents

# %%
title = 'active time as function of d'
plt.title(title)
plt.xlabel('d')
plt.ylabel('active time')
plt.plot(list(static_line_results['d']),list(static_line_results['active_time']))
plt.plot(list(traveling_line_results['d']),list(traveling_line_results['active_time']))
plt.plot(list(separate_traveling_results['d']),list(separate_traveling_results['active_time']))
plt.plot(list(iterative_assignment_results['d']),list(iterative_assignment_results['active_time']))
plt.plot(list(clustering_assignment_results['d']),list(clustering_assignment_results['active_time']))
plt.legend(['static line', 'traveling line','separate traveling','iterative assignment','clustering assignment'])
# plt.savefig('./plots/'+title+'.png')
plt.show()

# %% [markdown]
# ### planner time as function of #agents

# %%
title = 'planner time as function of d'
plt.title(title)
plt.xlabel('d')
plt.ylabel('planner time')
plt.plot(list(static_line_results['d']),list(static_line_results['planner_time']))
plt.plot(list(traveling_line_results['d']),list(traveling_line_results['planner_time']))
plt.plot(list(separate_traveling_results['d']),list(separate_traveling_results['planner_time']))
plt.plot(list(iterative_assignment_results['d']),list(iterative_assignment_results['planner_time']))
plt.plot(list(clustering_assignment_results['d']),list(clustering_assignment_results['planner_time']))
plt.legend(['static line', 'traveling line','separate traveling','iterative assignment','clustering assignment'])
# plt.savefig('./plots/'+title+'.png')
plt.show()

# %% [markdown]
# ### #disabled as function of d

# %%
title = '#disabled as function of d'
plt.title(title)
plt.xlabel('d')
plt.ylabel('#disabled')
plt.plot(list(static_line_results['d']),list(static_line_results['num_disabled']))
plt.plot(list(traveling_line_results['d']),list(traveling_line_results['num_disabled']))
plt.plot(list(separate_traveling_results['d']),list(separate_traveling_results['num_disabled']))
plt.plot(list(iterative_assignment_results['d']),list(iterative_assignment_results['num_disabled']))
plt.plot(list(clustering_assignment_results['d']),list(clustering_assignment_results['num_disabled']))
plt.legend(['static line', 'traveling line','separate traveling','iterative assignment','clustering assignment'])
# plt.savefig('./plots/'+title+'.png')
plt.show()
